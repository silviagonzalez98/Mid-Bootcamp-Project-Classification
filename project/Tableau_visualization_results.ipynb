# %% [markdown]
# # Solutions Tableau

# %%
from IPython import display

# %% [markdown]
# 1) Convert the necessary measures to dimensions (the variables that are categorical in nature). When you use a separate sheet for this question, add a note in that sheet on which columns were changed

# %% [markdown]
# * [Columns changed: credit rating, income level, mailer type, offer accepted, overdraft protection, own your home, reward.]

# %% [markdown]
# 2) Imbalance check (customers who accepted vs. who did not accept the offer)

# %%
display.Image("./draft_solutions_tableau/question_2.png")

# %% [markdown]
# 3) Do a quick table calculation on the previous plot to check percentage of total for both yes and no.

# %%
display.Image("./draft_solutions_tableau/question_3.png")

# %% [markdown]
# 4) Now we will try to analyze certain characteristics / the differences between the people who accepted the offer vs people who did not accept the offer. Plot average Q1-Q4 balance vs Offer Accepted. Provide the values of averages as labels.

# %%
display.Image("./draft_solutions_tableau/question_4.png")

# %% [markdown]
# 5) Now for all the plots, change the style of the plot from bar chart to a line chart. This could be used for a visual trend.

# %%
display.Image("./draft_solutions_tableau/question_5.png")

# %% [markdown]
# Insight: The distribution is almost similar with both, with customers who accepted the offer generally having higher average quarterly balances.

# %% [markdown]
# 6) Consider a similar analysis for Household Size vs average balances for each quarter. You would observe a huge jump in average balance from Q1 to Q2 for households with size 8. - Try and explain that jump. Hint: Check the number of records we have for such customers. Do you see any anomaly.

# %%
display.Image("./draft_solutions_tableau/question_6.png")

# %% [markdown]
# Insight: There is definitely observed a huge jump in average balance from q1 to q2 for households with size 8, and the main reason is that there is only one customer in the dataset that represents household = 8, consequently moves all the metric.

# %% [markdown]
# 7) Create crosstab to see relations between offer accepted and the categorical variables overdraft protection, mailer type and credit rating.

# %%
display.Image("./draft_solutions_tableau/question_7.png")

# %% [markdown]
# Insight: Customers that accepted the offer mostly had received a postcard, and had a low (and medium) credit rating. This results a key insight for the bank.

# %% [markdown]
# 8) Based on the average balance for each customer, create four buckets : Category A, Category B, Category C, and Category D. Category A is from min value to 700, 701 to 1400, 1400 to 1900, and 1900 to 3366. Check the number of observations for each of the categories.

# %%
display.Image("./draft_solutions_tableau/question_8.png")
